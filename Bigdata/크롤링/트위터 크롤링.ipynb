# %%
# %pip install python-twitter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
twitter_consumer_key = "F6zPG4ijGYSDGTGOyjmXV3m97"
twitter_consumer_secret = "4CwlvErnD7LpKnPX9gHU1nPVeSd96xXPaRyRQ3IjaXNtvb1MDg"
twitter_access_token = "2808781723-IGKuIyCIMjrDUHS9RP1FIf1YXIAlTftftCRDQFI"
twitter_access_secret = "Qr5NlF5KwXTTVZuiUg2nuuDuDyCDZUOVn8Jik2jEgQtnI"

import twitter

twitter_api = twitter.Api(consumer_key=twitter_consumer_key,
                          consumer_secret=twitter_consumer_secret, 
                          access_token_key=twitter_access_token, 
                          access_token_secret=twitter_access_secret)

# %%
query = "펫티켓"
statuses = twitter_api.GetSearch(term=query, count=10000)

for status in statuses:
    print(status.text)
# Out:
# @quobacom 동의합니다 근데 제기랄 모라스일퀘하는데 자석펫없으니까 진짜토나와서... 메이플에게 속아넘어가줄수밖에 없다... 금고티켓도 직접 주워야하게 뿌리는 메이플 규탄합니다

# %%
# %pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import pandas as pd

# %%
# 토큰키 정보 입력
twitter_consumer_key = "F6zPG4ijGYSDGTGOyjmXV3m97"
twitter_consumer_secret = "4CwlvErnD7LpKnPX9gHU1nPVeSd96xXPaRyRQ3IjaXNtvb1MDg"
twitter_access_token = "2808781723-IGKuIyCIMjrDUHS9RP1FIf1YXIAlTftftCRDQFI"
twitter_access_secret = "Qr5NlF5KwXTTVZuiUg2nuuDuDyCDZUOVn8Jik2jEgQtnI"

# %%
# 인증 정보
auth = tweepy.OAuthHandler(twitter_consumer_key, twitter_consumer_secret)
auth.set_access_token(twitter_access_token, twitter_access_secret)
api = tweepy.API(auth)

# %%
# 인증 시도
try:
   api.verify_credentials()
   print('Auth OK')
except:
   print('Auth Error')
# Out:
# Auth OK

# %%
# 트윗 컬렉트
query = '펫티켓'
tweets = api.search_tweets(q=query, count=1000, lang='kr')           
# tweepy reference 참고해 더 많은 필터 넣을 수 있음

# 데이터프레임에 넣기
df_tweets = pd.DataFrame()
#df_tweets['tweetId'] = [tweet.id for tweet in tweets]
#df_tweets['userName'] = [tweet.user.name for tweet in tweets]
#df_tweets['createdAt'] = [tweet.created_at for tweet in tweets]
df_tweets['text'] = [tweet.text.encode('utf-8') for tweet in tweets]

print(df_tweets)
# Out:
# Empty DataFrame
# Columns: [text]
# Index: []

# %% [markdown]
# 안나와....

# %% [markdown]
# 1. https://m.blog.naver.com/nonamed0000/220912854545

# %%
import tweepy
import requests

# 트위터 앱의 Keys and Access Tokens 탭 참조(자신의 설정 값을 넣어준다)
twitter_consumer_key = "F6zPG4ijGYSDGTGOyjmXV3m97"
twitter_consumer_secret = "4CwlvErnD7LpKnPX9gHU1nPVeSd96xXPaRyRQ3IjaXNtvb1MDg"

# 1. 인증요청(1차) : 개인 앱 정보 
auth = tweepy.OAuthHandler(twitter_consumer_key, twitter_consumer_secret)

twitter_access_token = "2808781723-IGKuIyCIMjrDUHS9RP1FIf1YXIAlTftftCRDQFI"
twitter_access_secret = "Qr5NlF5KwXTTVZuiUg2nuuDuDyCDZUOVn8Jik2jEgQtnI"

# 2. access 토큰 요청(2차) - 인증요청 참조변수 이용
auth.set_access_token(twitter_access_token, twitter_access_secret)

# %%
# 3. twitter API 생성  
api = tweepy.API(auth)

keyword = "반려견산책";     # 자신이 검색하고 싶은 키워드 입력 
search = [] # 크롤링 결과 저장할 변수   

cnt = 1
while(cnt <= 50):   # 10page 대상으로 크롤링
   tweets = api.search_tweets(keyword)
   for tweet in tweets:
       search.append(tweet)
   cnt += 1

print(len(search)) # 문서 길이 
print(search) # 첫번째 text 보기
# Out:
# 750
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
#전체 문서 보기

data = {}   # 전체 문서 추가
i = 0       # 문서 번호
for tweet in search:
    data['text'] = tweet.text   # text키에 text문서 저장
    print(i, " : ", data)   # 문서번호 : 문서내용
    i += 1
# Out:
# 0  :  {'text': "RT @hey_mdcr: 들어갔는데...\n이야 그날씨에도 기자정신투철하신분이 계실줄은 몰랐죠.\n아니면 창 밖에서 황금송아쥐랑 뛰는 종이병정의 폼을 보고 알아보시는 팬분이 있을줄은...\n\n'자식 이기는 부모 없다.' vtic 리더 청려, 폭우에도 반려…"}
# 1  :  {'text': "들어갔는데...\n이야 그날씨에도 기자정신투철하신분이 계실줄은 몰랐죠.\n아니면 창 밖에서 황금송아쥐랑 뛰는 종이병정의 폼을 보고 알아보시는 팬분이 있을줄은...\n\n'자식 이기는 부모 없다.' vtic 리더 청… https://t.co/lm1CGDJC1z"}
# 2  :  {'text': '동동아 생일축하해\n유기견 보호센터에서 데려온지 딱 2년됐네 반려견 처음키우는데\n어떻게 할지 몰랐는데 먼저 다가워줘서\n고마워! 오래 건강하게 잘살자\n(산책은 적당히 가자하고 힘들어) https://t.co/RUuhl57bcC'}
# 3  :  {'text': 'RT @kinsunni: 개와 함께 살지는 않지만 리쉬의 중요성을 다시 한 번 느끼며...ㅠㅠ 아무리 미국이어도 오프리쉬 산책 이렇게 위험합니다...\n반려견 공커를 통해 가족들이 하나로 묶여 단단해지는 내용이라 가족영화의 클리셰가 많이 보이긴 하지만…'}
# 4  :  {'text': 'RT @kinsunni: 개와 함께 살지는 않지만 리쉬의 중요성을 다시 한 번 느끼며...ㅠㅠ 아무리 미국이어도 오프리쉬 산책 이렇게 위험합니다...\n반려견 공커를 통해 가족들이 하나로 묶여 단단해지는 내용이라 가족영화의 클리셰가 많이 보이긴 하지만…'}
# 5  :  {'text': 'RT @kinsunni: 개와 함께 살지는 않지만 리쉬의 중요성을 다시 한 번 느끼며...ㅠㅠ 아무리 미국이어도 오프리쉬 산책 이렇게 위험합니다...\n반려견 공커를 통해 가족들이 하나로 묶여 단단해지는 내용이라 가족영화의 클리셰가 많이 보이긴 하지만…'}
# ...

# %% [markdown]
# ### IOPub ~~ 오류 나면 아래 코드로 환경설절 해주기 (단점 : 매번 실행할 때마다 해줘야함)
# jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10

# %%
# 전체 문서를 파일 저장

import os

wfile = open(os.getcwd()+"/twitter.csv", mode='w')   # 쓰기 모드
data = {}   # 전체 문서 추가
i = 0       # 문서 번호

for tweet in search:
    data['text'] = tweet.text   # text키에 text문서 저장
    wfile.write(data['text']+'\n')  # 파일 출력
    i += 1

wfile.close()

# %% [markdown]
# 2. https://hleecaster.com/python-twitter-api/ <br>
# https://honest-haemingway.tistory.com/9

# %%
twitter_consumer_key = "F6zPG4ijGYSDGTGOyjmXV3m97"
twitter_consumer_secret = "4CwlvErnD7LpKnPX9gHU1nPVeSd96xXPaRyRQ3IjaXNtvb1MDg"
twitter_access_token = "2808781723-IGKuIyCIMjrDUHS9RP1FIf1YXIAlTftftCRDQFI"
twitter_access_secret = "Qr5NlF5KwXTTVZuiUg2nuuDuDyCDZUOVn8Jik2jEgQtnI"

import twitter

twitter_api = twitter.Api(consumer_key=twitter_consumer_key,
                          consumer_secret=twitter_consumer_secret, 
                          access_token_key=twitter_access_token, 
                          access_token_secret=twitter_access_secret)

# %%
query = "펫티켓"
statuses = twitter_api.GetSearch(term=query, count=100)
for status in statuses:
    print(status.text)
# Out:
# @quobacom 동의합니다 근데 제기랄 모라스일퀘하는데 자석펫없으니까 진짜토나와서... 메이플에게 속아넘어가줄수밖에 없다... 금고티켓도 직접 주워야하게 뿌리는 메이플 규탄합니다

# %%
# 전체 문서를 파일 저장

import os

wfile = open(os.getcwd()+"/twitter_1.csv", mode='w')   # 쓰기 모드
data = {}   # 전체 문서 추가
i = 0       # 문서 번호

for tweet in search:
    data['text'] = tweet.text   # text키에 text문서 저장
    wfile.write(data['text']+'\n')  # 파일 출력
    i += 1

wfile.close()

# %%
query = "반려견산책"
statuses = twitter_api.GetSearch(term=query, count=100)
for status in statuses:
    print(status.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 query = "반려견산책"
# ----> 2 statuses = twitter_api.GetSearch(term=query, count=100)
#       3 for status in statuses:
#       4     print(status.text)
#
# NameError: name 'twitter_api' is not defined

# %%
query = "반려견"
statuses = twitter_api.GetSearch(term=query, count=500)
for status in statuses:
    for tag in status.hashtags:
        print(tag.text)
# Out:
# KBS
# KBS뉴스
# 헤이마리
# 제로펫에프앤비
# 그래잇빌리
# 현존핫템
# 태연
# TAEYEON
# 나혼자산다
# 헤이마리
# 제로펫에프앤비
# 그래잇빌리
# 헤이마리
# 제로펫에프앤비
# 그래잇빌리
# 기다릴께_현지야
# 마리나갤러리
# 전시제목
# 안승하
# 일하는
# 오브제
# 도그데이즈
# 윤여정
# 유해진
# 커미션찾아요

# %%
from collections import Counter
query = "반려견산책"
statuses = twitter_api.GetSearch(term=query, count=500)
result = []
for status in statuses:
    for tag in status.hashtags:
        result.append(tag.text)
        
Counter(result).most_common(100)
# Out:
# [('반려견', 8),
#  ('산책', 5),
#  ('시바이누', 3),
#  ('시바견', 3),
#  ('반려동물', 3),
#  ('흑시바', 3),
#  ('토이푸들', 2),
#  ('푸들', 2),
#  ('강아지', 2),
#  ('복댕이', 2),
#  ('웅장이', 2),
#  ('순찰', 2),
#  ('음주운전', 2),
#  ('눈길', 1),
#  ('tmi_3개_적고_트친_5명에게_넘기기', 1),
#  ('장항송림산림욕장', 1),
#  ('찡찡', 1),
#  ('경로재탐색', 1),
#  ('SBS뉴스', 1),
#  ('송림산림욕장', 1),
#  ('충남서천', 1),
#  ('바다', 1),
#  ('슬로우영상', 1),
#  ('기본', 1),
#  ('댕댕', 1)]

# %% [markdown]
# 3. https://medium.com/@whj2013123218/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%84-%EC%9D%B4%EC%9A%A9%ED%95%9C-twitter-%ED%81%AC%EB%A1%A4%EB%A7%81-576f7b098daf

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time
from selenium.webdriver.common.keys import Keys
import datetime as dt

# %%
# 셀레니움 가동
driver = webdriver.Chrome(service = Service("C:/Temp/chromedriver"))
driver.implicitly_wait(3)
driver.get("https://twitter.com/?lang=ko")

# %%
startdate=dt.date(year=2022,month=1,day=1)
untildate=dt.date(year=2022,month=1,day=31)
enddate=dt.date(year=2022,month=6,day=30)

# %%
totalfreq=[]
while not enddate==startdate:
    url='https://twitter.com/search?q=%EB%B0%98%EB%A0%A4%EA%B2%AC%EC%82%B0%EC%B1%85&src=typed_query&f=top'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg'
    driver.get(url)
    html = driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    
    lastHeight = driver.execute_script("return document.body.scrollHeight")
while True:
        dailyfreq={'Date':startdate}
#     i=0 i는 페이지수
        wordfreq=0
        tweets=soup.find_all("p", {"class": "TweetTextSize"})
        wordfreq+=len(tweets)
            
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        
        newHeight = browser.execute_script("return document.body.scrollHeight")
        print(newHeight)
        if newHeight != lastHeight:
            html = browser.page_source
            soup=BeautifulSoup(html,'html.parser')
            tweets=soup.find_all("p", {"class": "TweetTextSize"})
            wordfreq=len(tweets)
        else:
            dailyfreq['Frequency']=wordfreq
            wordfreq=0
            totalfreq.append(dailyfreq)
            startdate=untildate
            untildate+=dt.timedelta(days=1)
            dailyfreq={}
            break
#         i+=1
        lastHeight = newHeight
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In [29], line 5
#       3 url='https://twitter.com/search?q=%EB%B0%98%EB%A0%A4%EA%B2%AC%EC%82%B0%EC%B1%85&src=typed_query&f=top'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg'
#       4 driver.get(url)
# ----> 5 html = driver.page_source
#       6 soup=BeautifulSoup(html,'html.parser')
#       8 lastHeight = driver.execute_script("return document.body.scrollHeight")
#
# File ~\Anaconda3\envs\data_venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:550, in WebDriver.page_source(self)
#     540 @property
#     541 def page_source(self) -> str:
#     542     """
#     543     Gets the source of the current page.
#     544
#    (...)
#     548             driver.page_source
#     549     """
# --> 550     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# ...

# %% [markdown]
# 너무 오래 걸림....

# %% [markdown]
# 4. https://kkiho.tistory.com/8

# %%
import tweepy

# %%
# 토큰키 정보 입력
twitter_consumer_key = "F6zPG4ijGYSDGTGOyjmXV3m97"
twitter_consumer_secret = "4CwlvErnD7LpKnPX9gHU1nPVeSd96xXPaRyRQ3IjaXNtvb1MDg"
twitter_access_token = "2808781723-IGKuIyCIMjrDUHS9RP1FIf1YXIAlTftftCRDQFI"
twitter_access_secret = "Qr5NlF5KwXTTVZuiUg2nuuDuDyCDZUOVn8Jik2jEgQtnI"

# %%
auth = tweepy.OAuthHandler(twitter_consumer_key,twitter_consumer_secret)
auth.set_access_token(twitter_access_token,twitter_access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
# wait_on_rate_limit 많은 요청이 있을 때, 대기시간을 조절해서 중간에 뻗지 않게 도와준다.

# %%
cursor = tweepy.Cursor(api.search_tweets,
                       q = '반려견산책')

# %%
for i in cursor.items():
    print(i._json)
    break
# Out:
# {'created_at': 'Wed Feb 01 13:52:36 +0000 2023', 'id': 1620782170397904896, 'id_str': '1620782170397904896', 'text': '사상혼샤\n반려견산책\n거찬군캠핑장\n어설픈빵\n위례마들렌\n캠프\n창원천아트 https://t.co/j2nb6KDQTH', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1620782155814019072, 'id_str': '1620782155814019072', 'indices': [38, 61], 'media_url': 'http://pbs.twimg.com/media/Fn4syI-WIAABX7E.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Fn4syI-WIAABX7E.jpg', 'url': 'https://t.co/j2nb6KDQTH', 'display_url': 'pic.twitter.com/j2nb6KDQTH', 'expanded_url': 'https://twitter.com/sundar0510/status/1620782170397904896/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 300, 'h': 190, 'resize': 'fit'}, 'medium': {'w': 300, 'h': 190, 'resize': 'fit'}, 'large': {'w': 300, 'h': 190, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1620782155814019072, 'id_str': '1620782155814019072', 'indic
# ...

# %%
file = open(f'{keyword}.txt','a+',encoding='utf-8') # 위에서 검색으로 정한 키워드
for tweet in cursor.items():
    file.write('Text : {}\nRetweet : {}\nFavorite : {}'\
    .format(tweet.text,tweet.retweet_cout,tweet.favorite_count))
    file.write('-'*180)
file.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [73], line 4
#       1 file = open(f'{keyword}.txt','a+',encoding='utf-8') # 위에서 검색으로 정한 키워드
#       2 for tweet in cursor.items():
#       3     file.write('Text : {}\nRetweet : {}\nFavorite : {}'\
# ----> 4     .format(tweet.full_text))
#       5     file.write('-'*180)
#       6 file.close()
#
# AttributeError: 'Status' object has no attribute 'full_text'

# %% [markdown]
# 5. https://blog.naver.com/PostView.nhn?blogId=pouerccat&logNo=221833693883

# %%
# !/usr/bin/python3.7\
# 작성자 pouerccat
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
from selenium.webdriver.common.by import By
import sys
from collections import OrderedDict

def OrderedSet(inlist):
    my_set = set()
    res = []
    for e in inlist:
        if e not in my_set:
            res.append(e)
            my_set.add(e)

    return res

# %%
#sys.stdout = open('C:/Users/280806/Desktop/blog/output.txt', 'w')
driver = webdriver.Chrome('C:/Users/280806/Desktop/forensic_hack/chromedriver.exe')
driver.implicitly_wait(1)
driver.get('https://twitter.com/blue_shad0w_')
time.sleep(3)
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    html = driver.page_source
    bs = BeautifulSoup(html, "html.parser")
    for el in bs.find_all(lang="und"):
        print(el.get_text())
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        html = driver.page_source
        bs = BeautifulSoup(html, "html.parser")
        for el in bs.find_all(lang="und"):
            print(el.get_text())
        break
    last_height = new_height
time.sleep(2)
sys.stdout = open('C:/Users/280806/Desktop/blog/output2.txt', 'w')
f= open('C:/Users/280806/Desktop/blog/output.txt')
inlist = f.readlines()
outlist=list(reversed(OrderedSet(inlist)))
for i in outlist:
    print(i)
driver.close()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13336\3635635430.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/280806/Desktop/forensic_hack/chromedriver.exe')
# 
# 
# ...

# %% [markdown]
# https://rachelsdotcom.tistory.com/72

# %%
import tweepy

# %%
# 트위터 Application에서 발급 받은 key 정보들
consumer_key = "F6zPG4ijGYSDGTGOyjmXV3m97"
consumer_secret = "4CwlvErnD7LpKnPX9gHU1nPVeSd96xXPaRyRQ3IjaXNtvb1MDg"
access_token = "2808781723-IGKuIyCIMjrDUHS9RP1FIf1YXIAlTftftCRDQFI"
access_token_secret = "Qr5NlF5KwXTTVZuiUg2nuuDuDyCDZUOVn8Jik2jEgQtnI"

# %%
# 1. 핸들러 생성 및 개인정보 인증요청
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# 2. 액세스 요청
auth.set_access_token(access_token, access_token_secret)

# %%
# 3. twitter API 생성
api = tweepy.API(auth)

keyword = "펫티켓" # 검색하고 싶은 키워드 입력
result = [] # 크롤링 텍스트를 저장 할 리스트 변수

for i in range(1,10) :
    tweets = api.search_tweets(keyword) # keyword 검색 실시. 결과가 tweets 변수에 담긴다.
    for tweet in tweets:
        result.append([tweet.id_str, tweet.text, tweet.created_at]) 
        # 크롤링 결과 리스트에 삽입. (id, 트윗내용, 생성날짜)
        
print(len(result)) # 크롤링하여 가져온 트윗 개수
#print(result[0]) # 수집결과 확인(첫번째 항목만)
print(result) # 전체를 확인하고 싶으면 이 코드로

# %% [markdown]
# BeautifualSoup으로 크롤링 <br>
# https://m.blog.naver.com/maniddo4001/221959740430

# %%
import time 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.common.exceptions import NoSuchElementException
import csv
from selenium.webdriver.chrome.service import Service
import html
from bs4 import BeautifulSoup

# %%
# 크롬창 띄우기
from selenium import webdriver
driver = webdriver.Chrome(service=Service('C:/Temp/chromedriver')) # 크롬 드라이버 로드
driver.implicitly_wait(3) 
driver.get('https://twitter.com/?lang=ko')

import time
time.sleep(2)

html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <html dir="ltr" lang="ko" style="overflow-y: scroll; overscroll-behavior-y: none; font-size: 15px;"><head><style>input::placeholder { user-select: none; -webkit-user-select: none; } iframe { color-scheme: auto; }</style><style>@font-face {
#   font-family: TwitterChirp;
#   src: url(https://abs.twimg.com/responsive-web/client-web/Chirp-Light.3a18e64a.woff2) format('woff2');
#   src: url(https://abs.twimg.com/responsive-web/client-web/Chirp-Light.7a5673aa.woff) format('woff');
#   font-weight: 300;
#   font-style: 'normal';
#   font-display: 'swap';
# }
# @font-face {
#   font-family: TwitterChirp;
#   src: url(https://abs.twimg.com/responsive-web/client-web/Chirp-Regular.80fda27a.woff2) format('woff2');
#   src: url(https://abs.twimg.com/responsive-web/client-web/Chirp-Regular.60b215ba.woff) format('woff');
#   font-weight: 400;
#   font-style: 'normal';
#   font-display: 'swap';
# }
# @font-face {
#   font-family: TwitterChirp;
# ...

# %%
target=driver.find_element(By.CSS_SELECTOR, "#react-root > div > div > div.css-1dbjc4n.r-18u37iz.r-13qz1uu.r-417010 > main > div > div > div > div > div > div.css-1dbjc4n.r-aqfbo4.r-gtdqiz.r-1gn8etr.r-1g40b8q > div:nth-child(1) > div > div > div > div > div > div.css-1dbjc4n.r-16y2uox.r-1wbh5a2.r-1pi2tsx.r-1777fci > div.css-1dbjc4n.r-1awozwy.r-18u37iz.r-16y2uox.r-1wbh5a2.r-4amgru.r-itp27i > div > div > div > form > div.css-1dbjc4n.r-1wbh5a2 > div > div > div > label > div.css-1dbjc4n.r-16y2uox.r-1wbh5a2 > div > input")

target.send_keys('반려견산책매너')
target.send_keys(Keys.ENTER)

# %%
tags_span = soup.select('span')
tags_p = soup.select('p')

print(tags_span)
print(tags_p)
# Out:
# [<span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0">최신 소식을 놓치지 마세요</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0">트위터를 사용하면 가장 먼저 알게 됩니다.</span>, <span class="css-901oao css-16my406 css-1hf3ou5 r-poiln3 r-a023e6 r-rjixqe r-bcqeeo r-qvutc0"><span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0">로그인</span></span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0">로그인</span>, <span class="css-901oao css-16my406 css-1hf3ou5 r-poiln3 r-a023e6 r-rjixqe r-bcqeeo r-qvutc0"><span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0">가입하기</span></span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0">가입하기</span>, <span class="css-901oao css-16my406 css-1hf3ou5 r-poiln3 r-a023e6 r-rjixqe r-bcqeeo r-qvutc0"></span>, <span class="css-901oao css-16my406 css-1hf3ou5 r-poiln3 r-a023e6 r-rjixqe r-bcqeeo r-qvutc0"></span>, <span class="css-901oao css-16my406 css-1hf3ou5 r-poiln3 r-1inkyih r-rjixqe r-bcqeeo r-qvutc0"></spa
# ...

# %%
class_title = soup.select('title')
id_atcmp_answer_20 = soup.select('#id__rvqbhqetw')
print(class_title)
print(id_atcmp_answer_20)
# Out:
# [<title>탐색하기 / 트위터</title>]
# []

# %% [markdown]
# https://rachelsdotcom.tistory.com/72

# %%
import requests
from bs4 import BeautifulSoup

webpage = requests.get("https://twitter.com/?lang=ko")
soup = BeautifulSoup(webpage.content, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# ...
